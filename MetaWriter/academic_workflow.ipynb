# %%
# !pip install scikit-learn numpy nltk rank-bm25

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MetaWriter
# Out:
# /content/drive/MyDrive/MetaWriter

# %%
# --- 步骤 1: 设置环境 ---

# 1.1 设置您的 API Key
from google.colab import userdata
import os

# 从 Colab Secrets (秘钥管理器) 中获取您的 API Key
# 请确保您已经在左侧的“钥匙”图标中设置了名为 'DASHSCOPE_API_KEY' 的秘钥
api_key = userdata.get('DASHSCOPE_API_KEY')

# 将其设置为环境变量，以便 academic_workflow.py 可以读取
os.environ['DASHSCOPE_API_KEY'] = api_key

print("API Key 已成功设置为环境变量。")


# 1.2 下载 NLTK 数据包
import nltk
print("\n正在下载 NLTK 数据包...")
try:
    nltk.download('stopwords', quiet=True)
    nltk.download('punkt', quiet=True)
    print("NLTK 数据包 'stopwords' 和 'punkt' 已成功下载或已是最新。")
except Exception as e:
    print(f"NLTK 下载时出错: {e}")

# 1.3 (可选) 挂载 Google Drive 并进入工作目录
# 如果您的文件存放在 Drive 中，请取消下面的注释并修改路径
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/您的项目文件夹路径
# print("已进入指定的 Google Drive 工作目录。")
# Out:
# API Key 已成功设置为环境变量。
#
# 正在下载 NLTK 数据包...
# NLTK 数据包 'stopwords' 和 'punkt' 已成功下载或已是最新。

# %%
import nltk
print("\n正在下载 NLTK 数据包...")
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
# Out:
# 正在下载 NLTK 数据包...
# True

# %%
# !python workflow.py
# Out:
# --- 启动：全自动学术手稿生成工作流 ---
# NLTK resources 'stopwords' and 'punkt' are available.
# 研究主题: Effects of Low- and High-Dose X-ray Radiation on Immune Activation and Immune Suppression
#
# --- 步骤 1: 知识检索 (RAG) ---
# 正在调用 Dashscope API，模型: qwen-max (max_tokens: 150, temp: 0.5)...
# 检索到 20 篇相关文章用于上下文。
#
#
# --- 开始处理手稿部分: Introduction ---
# 正在调用 Dashscope API，模型: qwen-max (max_tokens: 6000, temp: 0.7)...
#
# --- LLM 生成的初始 Introduction ---
# ### 1. Introduction
#
# ...
